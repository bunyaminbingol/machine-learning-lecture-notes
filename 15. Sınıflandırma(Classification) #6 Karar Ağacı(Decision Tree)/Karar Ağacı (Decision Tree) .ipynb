# %% [markdown]
# sklearn kütüphanesinde DecisionTreeClassifier'ın parametrelerinden olan criterion'u kullanacağız. Bunu kullanmamızın nedeni ise "gini" veya "entropy" kullanılabilmesini mümkün kılan bir yöntemdir. Parametresini herhangi birşey belirtmezsek "gini" kullanır ama özel olarak "entropy" yazarak kullanabiliriz.
# "Entropy" ve "gini"'nin farkı,
# entropy = ![image.png](attachment:image.png)
# gini ise entropy kavramının log 2 tabanında alınmadığı halidir, yani pi*pi dir

# %%
#1.kutuphaneler

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


#veri yukleme

veriler = pd.read_csv('veriler/veriler.csv')
x = veriler.iloc[:,1:4].values # Bağımsız değişkenler, boy, kilo ve yaş
y = veriler.iloc[:,4:].values # bağmlı değişken, cinsiyet

# %%
# verilerin eğitim ve test için bölünmesi

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 0)

# %%
# verilerin ölçeklenmesi

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(x_train) 
X_test = sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(criterion="entropy")

dtc.fit(X_train, y_train)

y_pred = dtc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1, 0],
#        [1, 6]], dtype=int64)

# %%
# Başarı Oranı
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
# Sonuç : 0.739961759082218
print(accuracy)
# Out:
# 0.875
